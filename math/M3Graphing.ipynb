# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
df_construction = pd.read_csv('C:/Users/vince/CTBA/M3/ConstructionTimeSeriesDataV2.csv')

# %%
df_construction
# Out:
#      Month Month-Year  Total Construction  Private Construction  \
# 0        1     Jan-02               59516                 45273
# 1        2     Feb-02               58588                 44475
# 2        3     Mar-02               63782                 49396
# 3        4     Apr-02               69504                 53283
# 4        5     May-02               73384                 55009
# ..     ...        ...                 ...                   ...
# 141    142     Oct-13               85193                 59370
# 142    143     Nov-13               77931                 55191
# 143    144     Dec-13               71502                 52132
# 144    145     Jan-14               64661                 47827
# 145    146     Feb-14               63368                 46647
#
#      Public Construction
# 0                  14243
# 1                  14113
# 2                  14386
# 3                  16221
# 4                  18375
# ..                   ...
# ...

# %%
#Rearranging the rows to go by Jan 2, Jan 3, Jan 4, etc.
df_construction = df_construction.reindex([0,12,24,36,48,60,72,84,96,108,120,132,144,1,13,25,37,49,61,73,85,97,109,121,133,145,2,14,26,38,50,62,74,86,98,110,122,134,3,15,27,39,51,63,75,87,99,111,123,135,4,16,28,40,52,64,76,88,100,112,124,136,5,17,29,41,53,65,77,89,101,113,125,137,6,18,30,42,54,66,78,90,102,114,126,138,7,19,31,43,55,67,79,91,103,115,127,139,8,20,32,44,56,68,80,92,104,116,128,140,9,21,33,45,57,69,81,93,105,117,129,141,10,22,34,46,58,70,82,94,106,118,130,142,11,23,35,47,59,71,83,95,107,119,131,143])

# %%
#Creating x and y variables to graph
x = (df_construction['Month-Year'])
y = (df_construction['Total Construction'])

# %%
fig,ax = plt.subplots()
ax.plot(x, y, linewidth=1.5, color = 'k')
ax.grid(False)

""" Enhance axes object """
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Date',fontsize='14',fontname='Times New Roman')
ax.set_ylabel('Total Construction Spending',fontsize='14',fontname='Times New Roman')
ax.set_xticks(x[::5])
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter('${x:1.0f}')

""" Enhance figure object """
fig.set_size_inches(18,6)
fig.suptitle("Total 2021 Construction Spending",fontsize='18',fontname='Times New Roman')
fig.savefig('Total 2021 Construction Spending.jpg', dpi=2000)
plt.show()

# %% [markdown]
# Aspect of the graph I am calling out: I am displaying the total construction spending over the months of 2021.
